# %%
import pandas as pd
trip_data = pd.read_csv('data/citibike-tripdata.csv', sep=',')
trip_data.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# 4                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.998522           366.0    Clinton Ave & Myrtle Ave
# ...

# %% [markdown]
# ### Метаданные
# * starttime — время начала поездки (дата, время);
# * stoptime — время окончания поездки (дата, время);
# * start station id — идентификатор стартовой стоянки;
# * start station name — название стартовой стоянки;
# * start station latitude, start station longitude — географическая широта и долгота стартовой стоянки;
# * end station id — идентификатор конечной стоянки;
# * end station name — название конечной стоянки;
# * end station latitude, end station longitude — географическая широта и долгота конечной стоянки;
# * bikeid — идентификатор велосипеда;
# * usertype — тип пользователя (Customer — клиент с подпиской на 24 часа или на три дня, Subscriber — подписчик с годовой арендой велосипеда);
# * birth year — год рождения клиента;
# * gender — пол клиента (0 — неизвестный, 1 — мужчина, 2 — женщина).

# %%
trip_data['start station id'].info()
trip_data['starttime'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 300000 entries, 0 to 299999
# Series name: start station id
# Non-Null Count   Dtype
# --------------   -----
# 299831 non-null  float64
# dtypes: float64(1)
# memory usage: 2.3 MB
# <class 'pandas.core.series.Series'>
# RangeIndex: 300000 entries, 0 to 299999
# Series name: starttime
# Non-Null Count   Dtype
# --------------   -----
# 300000 non-null  object
# dtypes: object(1)
# memory usage: 2.3+ MB

# %%
trip_data['start station id'].value_counts()
# Out:
# start station id
# 281.0     1928
# 2006.0    1909
# 519.0     1873
# 514.0     1845
# 426.0     1835
#           ...
# 3432.0      15
# 3599.0      11
# 2005.0       9
# 3704.0       7
# 3583.0       6
# Name: count, Length: 759, dtype: int64

# %%
trip_data['bikeid'].mode()
# Out:
# 0    33887
# Name: bikeid, dtype: int64

# %%
customer_count = trip_data[trip_data['usertype'] == 'Customer'].shape[0]
subscriber_count = trip_data[trip_data['usertype'] == 'Subscriber'].shape[0]
subscriber_count / 300000
# Out:
# 0.7740066666666666

# %%
male_count = trip_data[trip_data['gender'] == 1].shape[0]
female_count = trip_data[trip_data['gender'] == 2].shape[0]
male_count
# Out:
# 183582

# %%
startpoint_count = len(trip_data['start station id'].value_counts())
endpoint_count = len(trip_data['end station id'].value_counts())
endpoint_count != startpoint_count
# Out:
# True

# %%
trip_data['birth year'].max()
# Out:
# np.int64(2002)

# %%
trip_data['start station name'].value_counts()
# Out:
# start station name
# Grand Army Plaza & Central Park S    1928
# Central Park S & 6 Ave               1909
# Pershing Square North                1873
# 12 Ave & W 40 St                     1845
# West St & Chambers St                1835
#                                      ...
# NYCBS Depot - GOW                      15
# Franklin Ave & Empire Blvd             11
# Railroad Ave & Kay Ave                  9
# 47 Ave & Skillman Ave                   7
# Eastern Pkwy & Washington Ave           6
# Name: count, Length: 759, dtype: int64

# %%
trip_data['end station name'].value_counts()
# Out:
# end station name
# West St & Chambers St          1963
# 12 Ave & W 40 St               1909
# Pershing Square North          1850
# Central Park S & 6 Ave         1828
# E 17 St & Broadway             1804
#                                ...
# Exchange Place                    3
# Union St                          1
# Montrose Ave & Bushwick Ave       1
# Warren St                         1
# Liberty Light Rail                1
# Name: count, Length: 765, dtype: int64

# %%
trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
trip_data[trip_data['age'] > 60].shape[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
trip_data.head()
# Out:
#                   starttime                  stoptime  start station id  \
# 0  2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1  2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2  2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3  2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4  2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# 4                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.998522           366.0    Clinton Ave & Myrtle Ave
# ...

# %%
trip_data['starttime'] = pd.to_datetime(trip_data['starttime'], dayfirst = False)
trip_data['stoptime'] = pd.to_datetime(trip_data['stoptime'], dayfirst = False)
trip_data.head()
trip_data.loc[3,'stoptime'] - trip_data.loc[3,'starttime']
# Out:
# Timedelta('0 days 00:07:16.837000')

# %%
trip_data['weekend'] = trip_data['starttime'].dt.dayofweek
def is_weekend(day):
    if day == 5 or day == 6: day = 1
    else: day = 0
    return day
trip_data['weekend'] = trip_data['weekend'].apply(is_weekend)
trip_data['weekend'].value_counts()
# Out:
# weekend
# 0    184865
# 1    115135
# Name: count, dtype: int64

# %%
#melb_df['MonthSale'] = melb_df['Date'].dt.month
trip_data['time of day'] = trip_data['starttime'].dt.hour
def time_of_day(time):
    if 0 <= time <= 6: time = 'night'
    elif 6 < time <= 12: time = 'morning'
    elif 12 < time <= 18: time = 'day'
    else: time = 'evening'
    return time
trip_data['time of day'] = trip_data['time of day'].apply(time_of_day)
trip_data
# Out:
#                      starttime                stoptime  start station id  \
# 0      2018-09-01 00:00:05.269 2018-09-01 00:27:20.634             252.0
# 1      2018-09-01 00:00:11.281 2018-09-01 00:02:23.481             314.0
# 2      2018-09-01 00:00:20.649 2018-09-01 00:55:58.547            3142.0
# 3      2018-09-01 00:00:21.746 2018-09-01 00:07:38.583             308.0
# 4      2018-09-01 00:00:27.315 2018-09-01 02:21:25.308             345.0
# ...                        ...                     ...               ...
# 299995 2018-09-05 19:08:27.846 2018-09-05 19:15:51.494             494.0
# 299996 2018-09-05 19:08:28.370 2018-09-05 19:20:01.508            3016.0
# 299997 2018-09-05 19:08:27.509 2018-09-05 19:13:40.506            3686.0
# 299998 2018-09-05 19:08:29.230 2018-09-05 20:04:29.322             254.0
# 299999 2018-09-05 19:08:29.711 2018-09-05 19:12:14.762            3496.0
#
#                      start station name  start station latitude  \
# ...

# %%
trip_data['time of day'].value_counts()
# Out:
# time of day
# day        143012
# morning     95530
# evening     46373
# night       15085
# Name: count, dtype: int64
